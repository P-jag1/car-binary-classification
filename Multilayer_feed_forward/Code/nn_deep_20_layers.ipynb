# %%
import numpy as np
import time
from scipy import misc, ndimage
from PIL import Image
import matplotlib.pyplot as plt
import random
import os
from data_loader import *
from data_visualizer import *

np.random.seed(2018)

import keras
from keras.models import Sequential
from keras.layers import Activation, Dense, Flatten, Dropout
from keras.optimizers import SGD, Adam
from sklearn.metrics import accuracy_score, f1_score
from keras.models import load_model
from keras.utils import plot_model
from keras.optimizers import SGD, Adam
from keras.callbacks import CSVLogger, ReduceLROnPlateau
from keras_sequential_ascii import keras2ascii
from sklearn.metrics import accuracy_score, f1_score
# Out:
# Using TensorFlow backend.

# %%
#inicializace dat
x_train, y_train = load_data()
x_test, y_test = load_test_data()
print(x_train.shape)
print(x_test.shape)
# Out:
# (6625, 64, 64, 3)
# (700, 64, 64, 3)

# %%
#zobrazení příkladů trénovacího souboru
visualize_examples(x_train, y_train, 10)

# %%
#změna matice
x_train, x_test = change_matrix(x_train, x_test)
# Out:
# Dimenze trénovacího setu X:(6625, 12288)
# Dimenze trénovacího setu Y:(6625,)
# Dimenze testovacího setu X:(700, 12288)
# Dimenze testovacího setu Y:(700,)

# %%
# vytvoření modelu neuronové sítě
def train_model( x_train, y_train, epochs, batch_size, optimizer):
    
    #inicializace parametrů
    epochs_n = epochs
    batch_size_n = batch_size 
    unit_in_layer = 200
    
    #vytvoření modelu
    model = Sequential()
    model.add(Dense(units=400, activation = "relu", input_dim = x_train.shape[1]))
    Dropout(0.2)
    model.add(Dense(units=375,activation="relu"))
    Dropout(0.2)
    model.add(Dense(units=350,activation="relu"))
    Dropout(0.2)
    model.add(Dense(units=325,activation="relu"))
    Dropout(0.2)
    model.add(Dense(units=300,activation="relu"))
    Dropout(0.2)
    model.add(Dense(units=275,activation="relu"))
    Dropout(0.2)
    model.add(Dense(units=250,activation="relu"))
    Dropout(0.2)
    model.add(Dense(units=225,activation="relu"))
    Dropout(0.2)
    model.add(Dense(units=200,activation="relu"))
    Dropout(0.2)
    model.add(Dense(units=175,activation="relu"))
    Dropout(0.2)
    model.add(Dense(units=150,activation="relu"))
    Dropout(0.2)
    model.add(Dense(units=125,activation="relu"))
    Dropout(0.2)
    model.add(Dense(units=100,activation="relu"))
    Dropout(0.2)
    model.add(Dense(units=100,activation="relu"))
    Dropout(0.2)
    model.add(Dense(units=75,activation="relu"))
    Dropout(0.2)
    model.add(Dense(units=75,activation="relu"))
    Dropout(0.2)
    model.add(Dense(units=50,activation="relu"))
    Dropout(0.2)
    model.add(Dense(units=25,activation="relu"))
    Dropout(0.2)
    model.add(Dense(units=25,activation="relu"))
    Dropout(0.2)
    model.add(Dense(units=1,activation="sigmoid"))

    #nastavení optimizeru
    if (optimizer == 'sgd'):
        sgd = SGD(lr=0.01, momentum=0.0, decay=0.0, nesterov=True)
        model.compile(optimizer = sgd, loss = "binary_crossentropy", metrics = ["accuracy"])
        
    elif (optimizer == 'adam'):
        adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
        model.compile(optimizer = adam, loss = "binary_crossentropy", metrics = ["accuracy"])

    
    start = time.time()
    # vytvoření logu trénování
    csv_logger = CSVLogger('nn_deep_20_adam_pyramid_50e.log')
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                              patience=5, min_lr=0.001)
    # trénování modelu model.fit()
    history = model.fit(x_train, y_train, validation_split=0.2,  epochs = epochs_n, batch_size = batch_size_n, verbose = 1, callbacks=[csv_logger, reduce_lr])
    end = time.time() 
    
    # vytiskne přehled modelu
    print("Model took %0.2f seconds to train"%(end - start))
    print(model.summary())
    keras2ascii(model)
    print_graphs(history)
    
    # uložení modelu jako .h5
    model.save(r'C:\Users\Petr\Desktop\Bakalářská práce\Neural_networks\deep_nn\nn_deep_20_adam_pyramid_50e.h5')
    
    return history, model

# %%
# trénování modelu
history, model = train_model(x_train, y_train, 50, 32, 'adam')
# Out:
# Train on 5304 samples, validate on 1326 samples
# Epoch 1/50
# 5304/5304 [==============================] - 25s 5ms/step - loss: 0.4238 - acc: 0.8209 - val_loss: 0.2689 - val_acc: 0.8959
# Epoch 2/50
# 5304/5304 [==============================] - 24s 5ms/step - loss: 0.2845 - acc: 0.8925 - val_loss: 0.2118 - val_acc: 0.9284
# Epoch 3/50
# 5304/5304 [==============================] - 24s 4ms/step - loss: 0.2813 - acc: 0.8988 - val_loss: 0.2086 - val_acc: 0.9276
# Epoch 4/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.3643 - acc: 0.8518 - val_loss: 0.3074 - val_acc: 0.8952
# Epoch 5/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.2597 - acc: 0.9110 - val_loss: 0.2611 - val_acc: 0.9118
# Epoch 6/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.2566 - acc: 0.9003 - val_loss: 0.2101 - val_acc: 0.9253
# Epoch 7/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.2022 - acc: 0.9268 - val_loss: 0.1895 - val_acc: 0.9374
# Epoch 8/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.1757 - acc: 0.9434 - val_loss: 0.2181 - val_acc: 0.9389
# Epoch 9/50
# 5304/5304 [==============================] - 25s 5ms/step - loss: 0.2952 - acc: 0.8876 - val_loss: 0.1935 - val_acc: 0.9480
# Epoch 10/50
# 5304/5304 [==============================] - 24s 5ms/step - loss: 0.1825 - acc: 0.9372 - val_loss: 0.1782 - val_acc: 0.9480
# Epoch 11/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.1570 - acc: 0.9449 - val_loss: 0.2756 - val_acc: 0.9246
# Epoch 12/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.2532 - acc: 0.8986 - val_loss: 0.3535 - val_acc: 0.8771
# Epoch 13/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.2521 - acc: 0.9044 - val_loss: 0.2282 - val_acc: 0.9103
# Epoch 14/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.1969 - acc: 0.9295 - val_loss: 0.2540 - val_acc: 0.8793
# Epoch 15/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.1579 - acc: 0.9449 - val_loss: 0.1656 - val_acc: 0.9351
# Epoch 16/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.1402 - acc: 0.9519 - val_loss: 0.1651 - val_acc: 0.9502
# Epoch 17/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.2884 - acc: 0.8754 - val_loss: 0.6721 - val_acc: 0.5430
# Epoch 18/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.6212 - acc: 0.6276 - val_loss: 0.3534 - val_acc: 0.8643
# Epoch 19/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.2883 - acc: 0.8876 - val_loss: 0.2259 - val_acc: 0.9223
# Epoch 20/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.2700 - acc: 0.8965 - val_loss: 0.2401 - val_acc: 0.9140
# Epoch 21/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.2046 - acc: 0.9295 - val_loss: 0.2036 - val_acc: 0.9367
# Epoch 22/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.1958 - acc: 0.9297 - val_loss: 0.2363 - val_acc: 0.9306
# Epoch 23/50
# 5304/5304 [==============================] - 24s 4ms/step - loss: 0.2178 - acc: 0.9244 - val_loss: 0.1884 - val_acc: 0.9442
# Epoch 24/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.1659 - acc: 0.9416 - val_loss: 0.2241 - val_acc: 0.9261
# Epoch 25/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.1766 - acc: 0.9393 - val_loss: 0.1796 - val_acc: 0.9480
# Epoch 26/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.1548 - acc: 0.9474 - val_loss: 0.1828 - val_acc: 0.9457
# Epoch 27/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.1560 - acc: 0.9489 - val_loss: 0.1910 - val_acc: 0.9367
# Epoch 28/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.1581 - acc: 0.9482 - val_loss: 0.2223 - val_acc: 0.9268
# Epoch 29/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.1604 - acc: 0.9434 - val_loss: 0.1934 - val_acc: 0.9367
# Epoch 30/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.1522 - acc: 0.9508 - val_loss: 0.1738 - val_acc: 0.9449
# Epoch 31/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.1491 - acc: 0.9491 - val_loss: 0.1846 - val_acc: 0.9487
# Epoch 32/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.1319 - acc: 0.9561 - val_loss: 0.2058 - val_acc: 0.9344
# Epoch 33/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.1342 - acc: 0.9553 - val_loss: 0.1675 - val_acc: 0.9449
# Epoch 34/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.1315 - acc: 0.9574 - val_loss: 0.2138 - val_acc: 0.9306
# Epoch 35/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.2400 - acc: 0.9495 - val_loss: 1.0593 - val_acc: 0.6222
# Epoch 36/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.6793 - acc: 0.6129 - val_loss: 0.6156 - val_acc: 0.7089
# Epoch 37/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.5689 - acc: 0.7066 - val_loss: 0.3676 - val_acc: 0.8462
# Epoch 38/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.3166 - acc: 0.8714 - val_loss: 0.2190 - val_acc: 0.9201
# Epoch 39/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.1912 - acc: 0.9355 - val_loss: 0.2095 - val_acc: 0.9306
# Epoch 40/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.1635 - acc: 0.9466 - val_loss: 0.1858 - val_acc: 0.9412
# Epoch 41/50
# 5304/5304 [==============================] - 24s 4ms/step - loss: 0.2304 - acc: 0.9191 - val_loss: 0.8200 - val_acc: 0.4570
# Epoch 42/50
# 5304/5304 [==============================] - 26s 5ms/step - loss: 0.4535 - acc: 0.7828 - val_loss: 0.2740 - val_acc: 0.8989
# Epoch 43/50
# 5304/5304 [==============================] - 24s 5ms/step - loss: 0.2620 - acc: 0.9029 - val_loss: 0.2254 - val_acc: 0.9186
# Epoch 44/50
# 5304/5304 [==============================] - 25s 5ms/step - loss: 0.1846 - acc: 0.9353 - val_loss: 0.1899 - val_acc: 0.9344
# Epoch 45/50
# 5304/5304 [==============================] - 25s 5ms/step - loss: 0.1699 - acc: 0.9419 - val_loss: 0.2143 - val_acc: 0.9344
# Epoch 46/50
# 5304/5304 [==============================] - 25s 5ms/step - loss: 0.1572 - acc: 0.9497 - val_loss: 0.1817 - val_acc: 0.9487
# Epoch 47/50
# 5304/5304 [==============================] - 24s 5ms/step - loss: 0.1601 - acc: 0.9470 - val_loss: 0.2316 - val_acc: 0.9389
# Epoch 48/50
# 5304/5304 [==============================] - 22s 4ms/step - loss: 0.5127 - acc: 0.7419 - val_loss: 0.3056 - val_acc: 0.8824
# Epoch 49/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.2928 - acc: 0.8844 - val_loss: 0.2372 - val_acc: 0.9201
# Epoch 50/50
# 5304/5304 [==============================] - 23s 4ms/step - loss: 0.2144 - acc: 0.9208 - val_loss: 0.2376 - val_acc: 0.9170
# Model took 1165.56 seconds to train
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_101 (Dense)            (None, 400)               4915600
# _________________________________________________________________
# dense_102 (Dense)            (None, 375)               150375
# _________________________________________________________________
# dense_103 (Dense)            (None, 350)               131600
# _________________________________________________________________
# dense_104 (Dense)            (None, 325)               114075
# _________________________________________________________________
# dense_105 (Dense)            (None, 300)               97800
# _________________________________________________________________
# dense_106 (Dense)            (None, 275)               82775
# _________________________________________________________________
# dense_107 (Dense)            (None, 250)               69000
# _________________________________________________________________
# dense_108 (Dense)            (None, 225)               56475
# _________________________________________________________________
# dense_109 (Dense)            (None, 200)               45200
# _________________________________________________________________
# dense_110 (Dense)            (None, 175)               35175
# _________________________________________________________________
# dense_111 (Dense)            (None, 150)               26400
# _________________________________________________________________
# dense_112 (Dense)            (None, 125)               18875
# _________________________________________________________________
# dense_113 (Dense)            (None, 100)               12600
# _________________________________________________________________
# dense_114 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_115 (Dense)            (None, 75)                7575
# _________________________________________________________________
# dense_116 (Dense)            (None, 75)                5700
# _________________________________________________________________
# dense_117 (Dense)            (None, 50)                3800
# _________________________________________________________________
# dense_118 (Dense)            (None, 25)                1275
# _________________________________________________________________
# dense_119 (Dense)            (None, 25)                650
# _________________________________________________________________
# dense_120 (Dense)            (None, 1)                 26
# =================================================================
# Total params: 5,785,076
# Trainable params: 5,785,076
# Non-trainable params: 0
# _________________________________________________________________
# None
#            OPERATION           DATA DIMENSIONS   WEIGHTS(N)   WEIGHTS(%)
#
#                Input   #####       12288
#                Dense   XXXXX -------------------   4915600    85.0%
#                 relu   #####         400
#                Dense   XXXXX -------------------    150375     2.6%
#                 relu   #####         375
#                Dense   XXXXX -------------------    131600     2.3%
#                 relu   #####         350
#                Dense   XXXXX -------------------    114075     2.0%
#                 relu   #####         325
#                Dense   XXXXX -------------------     97800     1.7%
#                 relu   #####         300
#                Dense   XXXXX -------------------     82775     1.4%
#                 relu   #####         275
#                Dense   XXXXX -------------------     69000     1.2%
#                 relu   #####         250
#                Dense   XXXXX -------------------     56475     1.0%
#                 relu   #####         225
#                Dense   XXXXX -------------------     45200     0.8%
#                 relu   #####         200
#                Dense   XXXXX -------------------     35175     0.6%
#                 relu   #####         175
#                Dense   XXXXX -------------------     26400     0.5%
#                 relu   #####         150
#                Dense   XXXXX -------------------     18875     0.3%
#                 relu   #####         125
#                Dense   XXXXX -------------------     12600     0.2%
#                 relu   #####         100
#                Dense   XXXXX -------------------     10100     0.2%
#                 relu   #####         100
#                Dense   XXXXX -------------------      7575     0.1%
#                 relu   #####          75
#                Dense   XXXXX -------------------      5700     0.1%
#                 relu   #####          75
#                Dense   XXXXX -------------------      3800     0.1%
#                 relu   #####          50
#                Dense   XXXXX -------------------      1275     0.0%
#                 relu   #####          25
#                Dense   XXXXX -------------------       650     0.0%
#                 relu   #####          25
#                Dense   XXXXX -------------------        26     0.0%
#              sigmoid   #####           1

# %%
# vytvoření modelu jako obrázku
os.environ["PATH"] += os.pathsep + 'C:/Program Files (x86)/Graphviz2.38/bin/'
plot_model(model, to_file='model_plot_20_200u_layers.png', show_shapes=True, show_layer_names=True)

# %%
#odstranit stávající model
del model

# %%
#načtení uloženého modelu
model = load_model('nn_deep_20_adam_pyramid_200e.h5')

# %%
# metoda pro udělání predikce na testovacím souboru
def prediction_test(model, x_test, y_test):
    
    test_predictions = model.predict(x_test)
    test_predictions = np.round(test_predictions)

    # vrácení přesnosti predikce
    accuracy = accuracy_score(y_test, test_predictions)
    print("Přesnost testovacího datasetu: " + str(accuracy * 100) + "%")
    
    return test_predictions

# %%
# zobrazení testovacích dat
visualize_examples(x_test, y_test, 10)

# %%
# predikce testovacího souboru
test_predictions = prediction_test(model, x_test, y_test)
# Out:
# Přesnost testovacího setu: 50.0%

# %%
# zobrazení nesprávně označených obrázků
visualize_incorrect_labels(x_test, y_test, np.asarray(test_predictions).ravel())
# Out:
# počet špatných odhadů: 350
